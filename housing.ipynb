# %%
import pandas as pd
import numpy as np

# %%
fname = 'train.csv'
data = pd.read_csv(fname)
len(data)
data.head()
# Out:
#     ID     crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0   23  1.23247   0.0   8.14     0  0.538  6.142  91.7  3.9769    4  307
# 1  452  5.44114   0.0  18.10     0  0.713  6.655  98.2  2.3552   24  666
# 2   11  0.22489  12.5   7.87     0  0.524  6.377  94.3  6.3467    5  311
# 3  137  0.32264   0.0  21.89     0  0.624  5.942  93.5  1.9669    4  437
# 4  503  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
#
#    ptratio   black  lstat  medv
# 0     21.0  396.90  18.72  15.2
# 1     20.2  355.29  17.73  15.2
# 2     15.2  392.52  20.45  15.0
# 3     21.2  378.25  16.90  17.4
# 4     21.0  396.90   9.08  20.6

# %%
data.count()
data['indus'].value_counts()
data['chas'].value_counts()
data['crim'].value_counts()
data['zn'].value_counts()
data['nox'].value_counts()
data['rm'].value_counts()
data['age'].value_counts()
data['dis'].value_counts()
data['rad'].value_counts()
data['tax'].value_counts()
data['ptratio'].value_counts()
data['black'].value_counts()
data['lstat'].value_counts()
data['medv'].value_counts()
# Out:
# 50.0    6
# 23.1    5
# 19.3    5
# 21.4    4
# 23.9    4
# 20.6    4
# 17.8    4
# 17.4    3
# 15.2    3
# 25.0    3
# 19.1    3
# 27.5    3
# 22.8    3
# 19.4    3
# 22.0    3
# 24.3    3
# 19.0    2
# 20.3    2
# 33.4    2
# 21.7    2
# 21.8    2
# 14.1    2
# 23.8    2
# 22.9    2
# 12.7    2
# 19.8    2
# 8.3     2
# 18.6    2
# 24.7    2
# 14.6    2
#        ..
# 36.4    1
# 22.3    1
# 32.4    1
# 33.8    1
# 37.6    1
# 21.6    1
# 13.4    1
# 32.2    1
# 18.4    1
# 18.3    1
# 18.9    1
# 12.0    1
# 8.7     1
# 31.2    1
# 21.2    1
# 11.8    1
# 28.4    1
# 48.3    1
# 5.6     1
# 24.6    1
# 19.9    1
# 16.0    1
# 26.2    1
# 8.1     1
# 18.2    1
# 30.7    1
# 31.1    1
# 20.4    1
# 33.1    1
# 22.5    1
# Name: medv, dtype: int64

# %%
columns_target= ['medv']
columns_train = ['ID','crim','indus','nox','rm','age','dis','rad','tax','ptratio','black','lstat']

# %%
X= data[columns_train]
Y= data[columns_target]

# %%
X['lstat'].isnull().sum()
print(Y.head())
# Out:
#    medv
# 0  15.2
# 1  15.2
# 2  15.0
# 3  17.4
# 4  20.6

# %%
from sklearn import linear_model    
clf=linear_model.LinearRegression()
clf.fit(X, Y)
test = pd.read_csv('test.csv')
Z = test[columns_train]
print(Z.head())
pred = clf.predict(Z)
print pred
for i in pred:
    print(i)
np.savetxt('solution.csv',pred,delimiter=' ')
# Out:
#     ID      crim  indus    nox     rm    age     dis  rad  tax  ptratio  \
# 0  132   1.19294  21.89  0.624  6.326   97.7  2.2710    4  437     21.2
# 1  374  11.10810  18.10  0.668  4.906  100.0  1.1742   24  666     20.2
# 2  343   0.02498   1.89  0.518  6.540   59.7  6.2669    1  422     15.9
# 3  128   0.25915  21.89  0.624  5.693   96.0  1.7883    4  437     21.2
# 4  108   0.13117   8.56  0.520  6.127   85.2  2.1224    5  384     20.9
#
#     black  lstat
# 0  396.90  12.26
# 1  396.90  34.77
# 2  389.96   8.65
# 3  392.11  17.19
# 4  387.69  14.09
# [[ 19.98124206]
#  [  5.14494208]
#  [ 23.91829817]
#  [ 14.95585025]
#  [ 20.92388689]
#  [ 23.53493509]
#  [ 28.5883121 ]
#  [ 24.13922579]
#  [ 19.11784476]
#  [ 12.13050619]
#  [ 14.64054443]
#  [ 41.30730808]
#  [ 18.70823892]
#  [ 10.33983177]
#  [ 32.70485312]
#  [ 15.95545785]
#  [ 24.43484136]
#  [ 38.67652549]
#  [ 21.4458879 ]
#  [ 28.14454599]
#  [ 21.06683109]
#  [ 26.59703478]
#  [ 32.17518112]
#  [ 14.96793247]
#  [ 22.48344106]
#  [ 27.67532047]
#  [  7.17022732]
#  [ 21.73776027]
#  [ 28.51483044]
#  [ 12.44323688]
#  [ 21.92445283]
#  [ 19.64600515]
#  [ 21.22139267]
#  [ 21.08551678]
#  [ 12.8449815 ]
#  [ 19.98056353]
#  [ 24.62293824]
#  [ 27.22333467]
#  [ 22.51057377]
#  [ 22.84289341]
#  [ 19.73314964]
#  [ 31.53791481]
#  [ 26.60907825]
#  [ 15.41182965]
#  [ 29.91112206]
#  [ 25.11363653]
#  [ 19.50760017]
#  [ 17.61145322]
#  [ 40.15868033]
#  [ 30.86192448]
#  [ 28.04641061]
#  [ 23.29988258]
#  [ 15.87666826]
#  [ 29.4866736 ]
#  [ 19.86369308]
#  [ 17.41331415]
#  [ 21.02626872]
#  [ 23.81204308]
#  [ 35.53474442]
#  [ 21.34769215]
#  [ 20.06723093]
#  [ 22.71799352]
#  [ 18.08850842]
#  [ 28.26621518]
#  [ 32.61033219]
#  [ 24.15737736]
#  [ 21.22101092]
#  [ 13.52219981]
#  [ 38.61180076]
#  [ 21.78761166]
#  [ 19.64104974]
#  [ 33.68381147]
#  [ 18.64580857]
#  [ 24.36725139]
#  [ 23.48058606]
#  [ 31.94947245]
#  [ 28.40829342]
#  [ 32.82448219]
#  [ 13.98380441]
#  [ 20.76376567]
#  [ 25.72492454]
#  [ 24.25900892]
#  [ 12.73135973]
#  [ 24.42893658]
#  [ 26.15864366]
#  [ 13.28561421]
#  [ 27.30981689]
#  [ 34.24852781]
#  [ 25.17803088]
#  [ 32.61717832]
#  [ 21.35936869]
#  [ 27.18551517]
#  [ 21.39279835]
#  [ 10.07611809]
#  [ 24.20652953]
#  [ 33.26583874]
#  [ 24.84763791]
#  [ 18.43871755]
#  [ 24.1735711 ]
#  [ 26.63520367]
#  [ 16.30029224]
#  [ 22.77264174]
#  [ 30.74974409]
#  [ 29.96715321]
#  [ 25.89025154]
#  [ 15.1022609 ]
#  [ 20.22535789]
#  [ 20.91382688]
#  [ 26.84715152]
#  [ 12.77441785]]
# [ 19.98124206]
# [ 5.14494208]
# [ 23.91829817]
# [ 14.95585025]
# [ 20.92388689]
# [ 23.53493509]
# [ 28.5883121]
# [ 24.13922579]
# [ 19.11784476]
# [ 12.13050619]
# [ 14.64054443]
# [ 41.30730808]
# [ 18.70823892]
# [ 10.33983177]
# [ 32.70485312]
# [ 15.95545785]
# [ 24.43484136]
# [ 38.67652549]
# [ 21.4458879]
# [ 28.14454599]
# [ 21.06683109]
# [ 26.59703478]
# [ 32.17518112]
# [ 14.96793247]
# [ 22.48344106]
# [ 27.67532047]
# [ 7.17022732]
# [ 21.73776027]
# [ 28.51483044]
# [ 12.44323688]
# [ 21.92445283]
# [ 19.64600515]
# [ 21.22139267]
# [ 21.08551678]
# [ 12.8449815]
# [ 19.98056353]
# [ 24.62293824]
# [ 27.22333467]
# [ 22.51057377]
# [ 22.84289341]
# [ 19.73314964]
# [ 31.53791481]
# [ 26.60907825]
# [ 15.41182965]
# [ 29.91112206]
# [ 25.11363653]
# [ 19.50760017]
# [ 17.61145322]
# [ 40.15868033]
# [ 30.86192448]
# [ 28.04641061]
# [ 23.29988258]
# [ 15.87666826]
# [ 29.4866736]
# [ 19.86369308]
# [ 17.41331415]
# [ 21.02626872]
# [ 23.81204308]
# [ 35.53474442]
# [ 21.34769215]
# [ 20.06723093]
# [ 22.71799352]
# [ 18.08850842]
# [ 28.26621518]
# [ 32.61033219]
# [ 24.15737736]
# [ 21.22101092]
# [ 13.52219981]
# [ 38.61180076]
# [ 21.78761166]
# [ 19.64104974]
# [ 33.68381147]
# [ 18.64580857]
# [ 24.36725139]
# [ 23.48058606]
# [ 31.94947245]
# [ 28.40829342]
# [ 32.82448219]
# [ 13.98380441]
# [ 20.76376567]
# [ 25.72492454]
# [ 24.25900892]
# [ 12.73135973]
# [ 24.42893658]
# [ 26.15864366]
# [ 13.28561421]
# [ 27.30981689]
# [ 34.24852781]
# [ 25.17803088]
# [ 32.61717832]
# [ 21.35936869]
# [ 27.18551517]
# [ 21.39279835]
# [ 10.07611809]
# [ 24.20652953]
# [ 33.26583874]
# [ 24.84763791]
# [ 18.43871755]
# [ 24.1735711]
# [ 26.63520367]
# [ 16.30029224]
# [ 22.77264174]
# [ 30.74974409]
# [ 29.96715321]
# [ 25.89025154]
# [ 15.1022609]
# [ 20.22535789]
# [ 20.91382688]
# [ 26.84715152]
# [ 12.77441785]
